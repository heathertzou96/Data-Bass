# %% [markdown]
# # ETL PROJECT

# %%
Datasource:
    File Name: 
Datasource:
    File Name:
    File Name:

# %% [markdown]
# ## Extract, Transform, Load
#    Steps:
#    1. Retrieved the data from each source found on Kaggle.com and Data.world
#    2. Downloaded files as .csv to Local Drive
#    3. In Google Cloud (GC), new project created "all-about-that-database'
#    4. (GC) Created new storage bucket 'nba' and folder 'resources'
#    5. (GC) Uploaded .csv file to resources folder
#    6. (GC) In project, new table schema created "nba"
#    7. (GC) New tables created "INSERT NAMES HERE"
#    8. (GC) New view created by joining "TABLE NAME" and "TABLE NAME" on "INSERT FIELD NAME' -
#    #####note: This is for the salary information
#        Reasoning:
#    9. (GC) From "INSERT TABLE NAME" field names "INSERT FIELD NAMES" selected
#    10. (GC) Final view created by joining "TABLE NAME" and "TABLE NAME" on "INSERT FIELD NAME"
#        Reasoning:
#    11. Exported "TABLE NAME" as .csv to Local Drive to push onto GitHub

# %%
import pandas as pd
csv = 'nba_final_data_output.csv'
data = pd.read_csv(csv)

# %%
data.columns
# Out:
# Index(['name', 'career_FG_', 'birthPlace', 'position', 'college',
#        'career_FG3_', 'career_PTS', 'career_WS', 'career_PER', 'career_FT_',
#        'career_AST', 'career_TRB', 'highSchool', 'team', 'season', 'salary',
#        'Player', 'Date', 'Age', 'Weight', 'Height', 'Pre_draft_Team',
#        'Draft_Year', 'Conference'],
#       dtype='object')

# %%
# Field Names to be Adjusted:
    # career_FG_
    # birthPlace
    # career_FG3_
    # career_FT_
    # highSchool
    # name - drop
    # Date
    # Age
    # Weight
    # Height
    # Pre_draft_Team
    # Draft_Year
    # Conference

cleaned_names = data.rename(columns={'Player': 'player','career_FG_' : 'field_goal', 'birthPlace' : 'birth_place', 'career_FG3_' : 'three_ptr', 
                                      'career_FT_' : 'free_throw', 'highSchool': 'high_school', 'Date': 'date', 'Age': 'age', 
                                       'Weight' : 'weight', 'Height' : 'height', 'Pre_draft_Team': 'pre_draft_team', 'Draft_Year': 'draft_year',
                                       'Conference':'conference', 'career_PTS' : 'points', 'career_WS': 'win_share', 'career_PER': 'efficiency'})

# %%
cleaned_names
# Out:
#        field_goal                       birth_place  \
# 0            54.0  Washington, District of Columbia
# 1            54.0  Washington, District of Columbia
# 2            54.0  Washington, District of Columbia
# 3            54.0  Washington, District of Columbia
# 4            54.0  Washington, District of Columbia
# ...           ...                               ...
# 15995        49.3  Washington, District of Columbia
# 15996        49.3  Washington, District of Columbia
# 15997        49.3  Washington, District of Columbia
# 15998        49.3  Washington, District of Columbia
# 15999        49.3  Washington, District of Columbia
#
#                                                 position  \
# 0                                          Small Forward
# 1                                          Small Forward
# 2                                          Small Forward
# 3                                          Small Forward
# 4                                          Small Forward
# ...                                                  ...
# 15995  Power Forward and Small Forward and Shooting G...
# 15996  Power Forward and Small Forward and Shooting G...
# 15997  Power Forward and Small Forward and Shooting G...
# 15998  Power Forward and Small Forward and Shooting G...
# 15999  Power Forward and Small Forward and Shooting G...
#
#                              college  three_ptr  points  win_share  \
# 0           University of Notre Dame       17.1    24.3      134.2
# 1           University of Notre Dame       17.1    24.3      134.2
# 2           University of Notre Dame       17.1    24.3      134.2
# 3           University of Notre Dame       17.1    24.3      134.2
# 4           University of Notre Dame       17.1    24.3      134.2
# ...                              ...        ...     ...        ...
# 15995  University of Texas at Austin       38.1    27.0      141.7
# 15996  University of Texas at Austin       38.1    27.0      141.7
# 15997  University of Texas at Austin       38.1    27.0      141.7
# 15998  University of Texas at Austin       38.1    27.0      141.7
# 15999  University of Texas at Austin       38.1    27.0      141.7
#
#        efficiency  free_throw  career_AST  ...   season    salary  \
# 0            21.5        81.8         3.0  ...  1984-85    515000
# 1            21.5        81.8         3.0  ...  1984-85    515000
# 2            21.5        81.8         3.0  ...  1984-85    515000
# 3            21.5        81.8         3.0  ...  1984-85    515000
# 4            21.5        81.8         3.0  ...  1984-85    515000
# ...           ...         ...         ...  ...      ...       ...
# 15995        25.2        88.3         4.1  ...  2015-16  20158622
# 15996        25.2        88.3         4.1  ...  2015-16  20158622
# 15997        25.2        88.3         4.1  ...  2015-16  20158622
# 15998        25.2        88.3         4.1  ...  2015-16  20158622
# 15999        25.2        88.3         4.1  ...  2015-16  20158622
#
#                player       date  age weight height  pre_draft_team  \
# 0      Adrian Dantley  23-Mar-86   30    208    6'5      Notre Dame
# 1      Adrian Dantley  18-Mar-84   28    208    6'5      Notre Dame
# 2      Adrian Dantley  18-Dec-83   28    208    6'5      Notre Dame
# 3      Adrian Dantley  19-Oct-80   25    208    6'5      Notre Dame
# 4      Adrian Dantley   2-Dec-79   24    208    6'5      Notre Dame
# ...               ...        ...  ...    ...    ...             ...
# 15995    Kevin Durant  30-Nov-15   27    240    6'9           Texas
# 15996    Kevin Durant   5-Jan-15   26    240    6'9           Texas
# 15997    Kevin Durant  24-Mar-14   25    240    6'9           Texas
# 15998    Kevin Durant  10-Feb-14   25    240    6'9           Texas
# 15999    Kevin Durant  27-Jan-14   25    240    6'9           Texas
#
#        draft_year conference
# 0            1976        NaN
# 1            1976        NaN
# 2            1976        NaN
# 3            1976        NaN
# 4            1976        NaN
# ...           ...        ...
# 15995        2007       West
# 15996        2007       West
# 15997        2007       West
# 15998        2007       West
# 15999        2007       West
#
# [16000 rows x 23 columns]

# %%
del cleaned_names['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-ecd12ccf570f> in <module>
# ----> 1 del cleaned_names['name']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3514             # there was no match, this call should raise the appropriate
#    3515             # exception:
# -> 3516             self._data.delete(key)
#    3517
#    3518         # delete from the caches
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#     994         Delete selected item (items if non-unique) in-place.
#     995         """
# --> 996         indexer = self.items.get_loc(item)
#     997
#     998         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'

# %%
cleaned_names
# Out:
#        field_goal                       birth_place  \
# 0            54.0  Washington, District of Columbia
# 1            54.0  Washington, District of Columbia
# 2            54.0  Washington, District of Columbia
# 3            54.0  Washington, District of Columbia
# 4            54.0  Washington, District of Columbia
# ...           ...                               ...
# 15995        49.3  Washington, District of Columbia
# 15996        49.3  Washington, District of Columbia
# 15997        49.3  Washington, District of Columbia
# 15998        49.3  Washington, District of Columbia
# 15999        49.3  Washington, District of Columbia
#
#                                                 position  \
# 0                                          Small Forward
# 1                                          Small Forward
# 2                                          Small Forward
# 3                                          Small Forward
# 4                                          Small Forward
# ...                                                  ...
# 15995  Power Forward and Small Forward and Shooting G...
# 15996  Power Forward and Small Forward and Shooting G...
# 15997  Power Forward and Small Forward and Shooting G...
# 15998  Power Forward and Small Forward and Shooting G...
# 15999  Power Forward and Small Forward and Shooting G...
#
#                              college  three_ptr  points  win_share  \
# 0           University of Notre Dame       17.1    24.3      134.2
# 1           University of Notre Dame       17.1    24.3      134.2
# 2           University of Notre Dame       17.1    24.3      134.2
# 3           University of Notre Dame       17.1    24.3      134.2
# 4           University of Notre Dame       17.1    24.3      134.2
# ...                              ...        ...     ...        ...
# 15995  University of Texas at Austin       38.1    27.0      141.7
# 15996  University of Texas at Austin       38.1    27.0      141.7
# 15997  University of Texas at Austin       38.1    27.0      141.7
# 15998  University of Texas at Austin       38.1    27.0      141.7
# 15999  University of Texas at Austin       38.1    27.0      141.7
#
#        efficiency  free_throw  career_AST  ...   season    salary  \
# 0            21.5        81.8         3.0  ...  1984-85    515000
# 1            21.5        81.8         3.0  ...  1984-85    515000
# 2            21.5        81.8         3.0  ...  1984-85    515000
# 3            21.5        81.8         3.0  ...  1984-85    515000
# 4            21.5        81.8         3.0  ...  1984-85    515000
# ...           ...         ...         ...  ...      ...       ...
# 15995        25.2        88.3         4.1  ...  2015-16  20158622
# 15996        25.2        88.3         4.1  ...  2015-16  20158622
# 15997        25.2        88.3         4.1  ...  2015-16  20158622
# 15998        25.2        88.3         4.1  ...  2015-16  20158622
# 15999        25.2        88.3         4.1  ...  2015-16  20158622
#
#                player       date  age weight height  pre_draft_team  \
# 0      Adrian Dantley  23-Mar-86   30    208    6'5      Notre Dame
# 1      Adrian Dantley  18-Mar-84   28    208    6'5      Notre Dame
# 2      Adrian Dantley  18-Dec-83   28    208    6'5      Notre Dame
# 3      Adrian Dantley  19-Oct-80   25    208    6'5      Notre Dame
# 4      Adrian Dantley   2-Dec-79   24    208    6'5      Notre Dame
# ...               ...        ...  ...    ...    ...             ...
# 15995    Kevin Durant  30-Nov-15   27    240    6'9           Texas
# 15996    Kevin Durant   5-Jan-15   26    240    6'9           Texas
# 15997    Kevin Durant  24-Mar-14   25    240    6'9           Texas
# 15998    Kevin Durant  10-Feb-14   25    240    6'9           Texas
# 15999    Kevin Durant  27-Jan-14   25    240    6'9           Texas
#
#        draft_year conference
# 0            1976        NaN
# 1            1976        NaN
# 2            1976        NaN
# 3            1976        NaN
# 4            1976        NaN
# ...           ...        ...
# 15995        2007       West
# 15996        2007       West
# 15997        2007       West
# 15998        2007       West
# 15999        2007       West
#
# [16000 rows x 23 columns]
